# %%
# Data Toolkit

# %%
# Q1] What is NumPy, and why is it widely used in Python

'''NumPy is a Python library used for numerical and scientific computing.
It provides fast and efficient array operations.
NumPy supports large, multi-dimensional arrays and matrices.
It is widely used because it is faster than Python lists.
Many data science libraries are built on top of NumPy.'''

# %%
# Q2] How does broadcasting work in NumPy

'''Broadcasting allows NumPy to perform operations on arrays of different shapes.
Smaller arrays are automatically expanded to match larger ones.
This avoids writing loops manually.
It makes code shorter and faster.
Broadcasting improves performance significantly.'''

# %%
# Q3] What is a Pandas DataFrame

'''A DataFrame is a two-dimensional data structure in Pandas.
It stores data in rows and columns like a table.
Each column can have a different data type.
It is easy to filter, analyze, and modify data.
DataFrames are widely used in data analysis.'''

# %%
# Q4]  Explain the use of the groupby() method in Pandas

'''The groupby() method groups data based on a column.
It is used for aggregation like sum, mean, and count.
It helps analyze data category-wise.
It is commonly used in reporting.
It simplifies complex data analysis tasks.'''

# %%
# Q5] Why is Seaborn preferred for statistical visualizations

'''Seaborn provides high-level statistical plots.
It works smoothly with Pandas DataFrames.
The graphs are visually attractive by default.
It requires less code than Matplotlib.
It is ideal for data exploration.'''

# %%
# Q6]  What are the differences between NumPy arrays and Python lists

'''NumPy arrays store elements of the same type.
Python lists can store mixed data types.
NumPy arrays are faster and memory-efficient.
Lists are more flexible.
Arrays are better for numerical operations.'''

# %%
# Q7] What is a heatmap, and when should it be used

'''A heatmap displays data values using colors.
It is commonly used for correlation matrices.
Darker colors show higher values.
It helps identify patterns quickly.
Heatmaps are popular in data analysis.'''

# %%
# Q8] What does the term “vectorized operation” mean in NumPy

'''Vectorized operations apply operations to entire arrays at once.
They remove the need for loops.
This makes code faster and cleaner.
NumPy internally optimizes these operations.
They improve performance significantly.'''

# %%
# Q9] How does Matplotlib differ from Plotly

'''Matplotlib creates static plots.
Plotly creates interactive visualizations.
Plotly supports zooming and hovering.
Matplotlib is simpler for basic plots.
Plotly is preferred for dashboards.'''

# %%
# Q10] What is the significance of hierarchical indexing in Pandas

'''Hierarchical indexing allows multiple index levels.
It helps work with higher-dimensional data.
Complex data becomes easier to organize.
It supports advanced slicing.
It is useful in time-series and grouped data.'''

# %%
# Q11] What is the role of Seaborn’s pairplot() function

'''pairplot() creates pairwise plots between variables.
It shows relationships between features.
It includes histograms and scatter plots.
It is useful for exploratory data analysis.
It helps detect correlations.'''

# %%
# Q12]  What is the purpose of the describe() function in Pandas

'''The describe() function gives summary statistics.
It shows count, mean, min, max, and quartiles.
It works mainly on numerical data.
It helps understand data distribution.
It is often the first analysis step.'''

# %%
# Q13]  Why is handling missing data important in Pandas

'''Missing data can affect analysis results.
It may cause errors in calculations.
Handling missing values improves accuracy.
Pandas provides methods like fillna() and dropna().
Clean data leads to better insights.'''

# %%
# Q14] What are the benefits of using Plotly for data visualization


'''Plotly provides interactive graphs.
It supports web-based visualization.
Graphs are visually appealing.
It is suitable for dashboards.
It supports 3D plots easily.'''

# %%
# Q15]  How does NumPy handle multidimensional arrays

'''NumPy supports n-dimensional arrays.
These arrays are stored efficiently in memory.
Operations are performed using optimized C code.
It supports reshaping and slicing.
This makes complex calculations easier.'''

# %%
# Q16] What is the role of Bokeh in data visualization

'''Bokeh is used for interactive visualizations.
It is suitable for web applications.
It handles large datasets well.
It provides dynamic updates.
It is used in dashboards.'''

# %%
# Q17] Explain the difference between apply() and map() in Pandas

'''map() works on a single Series.
apply() works on rows or columns of DataFrames.
apply() is more flexible.
map() is simpler and faster.
Both help transform data.'''

# %%
# Q18] What are some advanced features of NumPy

'''Broadcasting
Vectorized operations
Linear algebra functions
Random number generation
Memory-efficient storage'''

# %%
# Q19]  How does Pandas simplify time series analysis

'''Pandas has built-in time series tools.
It supports date indexing.
Resampling is easy.
Rolling operations are available.
Time-based filtering is simple.'''

# %%
# Q20] What is the role of a pivot table in Pandas

'''Pivot tables summarize data.
They group and aggregate values.
They are useful for reports.
They work like Excel pivot tables.
They simplify data analysis.'''

# %%
# Q21] Why is NumPy’s array slicing faster than Python’s list slicing

'''NumPy arrays use contiguous memory.
Slicing creates views instead of copies.
Operations are optimized in C.
Less overhead is involved.
Hence, NumPy slicing is faster.'''

# %%
# Q22]  What are some common use cases for Seaborn?

'''Statistical data visualization
Correlation analysis
Distribution plots
Categorical analysis
Exploratory data analysis'''

# %%
# Practical

# %%
# Q1] How do you create a 2D NumPy array and calculate the sum of each row

import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
print(arr.sum(axis=1))
# Out:
# [ 6 15]

# %%
# Q2] Write a Pandas script to find the mean of a specific column in a DataFrame

import pandas as pd
df = pd.DataFrame({"marks":[70,80,90]})
print(df["marks"].mean())
# Out:
# 80.0

# %%
# Q3] Create a scatter plot using Matplotlib

import matplotlib.pyplot as plt
plt.scatter([1,2,3],[4,5,6])
plt.show()

# %%
# Q4]  How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap

import seaborn as sns
import pandas as pd

df = pd.DataFrame({"a":[1,2,3],"b":[4,5,6]})
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# Q5]  Generate a bar plot using Plotly

import plotly.express as px
df = px.data.tips()
px.bar(df, x="day", y="total_bill").show()

# %%
# Q6] Create a DataFrame and add a new column based on an existing column

df["double_marks"] = df["marks"] * 2

# %%
# Q7] Write a program to perform element-wise multiplication of two NumPy arrays

a = np.array([1,2,3])
b = np.array([4,5,6])
print(a * b)
# Out:
# [ 4 10 18]

# %%
# Q8] Create a line plot with multiple lines using Matplotlib

plt.plot([1,2,3],[2,4,6])
plt.plot([1,2,3],[1,3,5])
plt.show()

# %%
# Q9] Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold


df[df["marks"] > 75]

# %%
# Q10] Create a histogram using Seaborn to visualize a distribution

sns.histplot(df["marks"])

# %%
# Q11] Perform matrix multiplication using NumPy

print(np.dot(arr, arr.T))
# Out:
# [[14 32]
#  [32 77]]

# %%
# Q12]  Use Pandas to load a CSV file and display its first 5 rows

pd.read_csv("data.csv").head(5)

# %%
# Q13] Create a 3D scatter plot using Plotly.

px.scatter_3d(df, x="total_bill", y="tip", z="size").show()
