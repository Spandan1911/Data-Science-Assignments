# %%
# Theory Questions

# %%
# Q1] What is the difference between a function and a method in Python?

'''A function is a block of reusable code that performs a specific task and is defined using the def keyword. 
It can exist independently and does not belong to any class.
A method is also a function, but it is associated with an object or class.
Methods are called using an object, while functions are called directly.
For example, len(list) is a function, but list.append() is a method.
Methods usually work on the data of the object they belong to.'''

# %%
#  Q2] Explain the concept of function arguments and parameters in Python. 

'''Parameters are variables defined in the function declaration.
Arguments are the actual values passed to the function when it is called.
Parameters act as placeholders for arguments.
Python supports positional, keyword, default, and variable-length arguments.
Example: In def add(a, b), a and b are parameters, while add(2, 3) uses arguments.'''

# %%
# Q3] What are the different ways to define and call a function in Python?

'''Functions are defined using the def keyword followed by the function name.
They can be called by writing the function name with parentheses.
Python allows functions with parameters, default values, and return values.
Anonymous functions can be defined using lambda.
Functions can also be called inside other functions or loops.'''

# %%
# Q4] What is the purpose of the `return` statement in a Python function?

'''The return statement sends a value back to the caller after function execution.
It helps reuse results outside the function.
A function can return multiple values using tuples.
If return is not used, the function returns None by default.
Example: return a + b sends the sum back to the calling code.'''

# %%
# Q5] What are iterators in Python and how do they differ from iterables?

'''An iterable is an object that can be looped over, like lists or tuples.
An iterator is an object that keeps track of iteration state.
Iterables use the __iter__() method.
Iterators use both __iter__() and __next__() methods.
All iterators are iterables, but not all iterables are iterators.'''

# %%
# Q6] Explain the concept of generators in Python and how they are defined.

'''Generators are special functions that produce values one at a time.
They use the yield keyword instead of return.
Generators pause execution and resume when needed.
They are memory-efficient for large datasets.
Example: A generator yielding numbers using a loop.'''

# %%
# Q7] What are the advantages of using generators over regular functions?

'''Generators consume less memory than regular functions.
They generate values only when required.
They are faster for large data processing.
Code becomes cleaner and more readable.
Ideal for infinite sequences and streaming data.'''

# %%
# Q8] What is a lambda function in Python and when is it typically used?

'''A lambda function is a small anonymous function.
It is written using the lambda keyword.
It can have multiple arguments but only one expression.
Used for short, simple operations.
Commonly used with map(), filter(), and sorted().'''

# %%
# Q9] Explain the purpose and usage of the `map()` function in Python.

'''The map() function applies a function to every item in an iterable.
It returns a map object.
Useful for transforming data.
It avoids writing loops explicitly.
Example: Converting a list of numbers to their squares.'''

# %%
# Q10] What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

'''map() transforms each element in a sequence.
filter() selects elements based on a condition.
reduce() combines elements into a single value.
reduce() is available in the functools module.
All three support functional programming in Python.'''

# %%
# Q11] Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13]; 

'''Given list: [47, 11, 42, 13]
Step 1: 47 + 11 = 58
Step 2: 58 + 42 = 100
Step 3: 100 + 13 = 113
Final answer is 113.'''

# %%
# Practical Questions:

# %%
# Q1]  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def sum_of_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total

# %%
# Q2] Create a Python function that accepts a string and returns the reverse of that string.

def reverse_string(s):
    return s[::-1]

# %%
# Q3] Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def square_list(nums):
    return [n*n for n in nums]

# %%
# Q4] Write a Python function that checks if a given number is prime or not from 1 to 200.

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True

# %%
# Q5]  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

class Fibonacci:
    def __init__(self, n):
        self.a, self.b, self.count = 0, 1, n
    def __iter__(self):
        return self
    def __next__(self):
        if self.count <= 0:
            raise StopIteration
        self.a, self.b = self.b, self.a + self.b
        self.count -= 1
        return self.a

# %%
# Q6] Write a generator function in Python that yields the powers of 2 up to a given exponent.

def powers_of_two(n):
    for i in range(n+1):
        yield 2**i

# %%
# Q7]  Implement a generator function that reads a file line by line and yields each line as a string.

def read_file(filename):
    with open(filename) as f:
        for line in f:
            yield line.strip()

# %%
# Q8] Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

data = [(1,3),(4,1),(2,2)]
sorted_data = sorted(data, key=lambda x: x[1])

# %%
# Q9] Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

celsius = [0, 20, 30]
fahrenheit = list(map(lambda c: (c*9/5)+32, celsius))

# %%
# Q10] Create a Python program that uses `filter()` to remove all the vowels from a given string.

s = "hello world"
result = "".join(filter(lambda x: x.lower() not in "aeiou", s))

# %%
''' Q11] Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map '''



orders = [
    (34587, 4, 40.95),
    (98762, 5, 56.80),
    (77226, 3, 32.95),
    (88112, 3, 24.99)
]

result = list(map(
    lambda x: (x[0], x[1]*x[2] + 10 if x[1]*x[2] < 100 else x[1]*x[2]),
    orders
))
