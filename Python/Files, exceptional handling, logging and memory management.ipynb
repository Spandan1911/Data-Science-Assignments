# %%
# Files, exceptional handling, logging and memory management Questions

# %%
# Q1] What is the difference between interpreted and compiled languages

'''Interpreted languages execute code line by line at runtime.
Compiled languages convert the entire code into machine code before execution.
Python is an interpreted language, while C and C++ are compiled languages.
Interpreted languages are easier to debug.
Compiled languages generally run faster.'''

# %%
# Q2] What is exception handling in Python

'''Exception handling is a way to manage runtime errors in a program.
It prevents the program from crashing unexpectedly.
Python uses try, except, else, and finally blocks.
Errors are handled gracefully.
It improves program reliability.'''

# %%
# Q3] What is the purpose of the finally block in exception handling

'''The finally block always executes, whether an exception occurs or not.
It is mainly used for cleanup tasks.
Common uses include closing files or releasing resources.
It ensures important code always runs.
This makes programs safer.'''

# %%
# Q4]  What is logging in Python

'''Logging is used to record program events.
It helps track errors, warnings, and information messages.
Python provides the built-in logging module.
Logs help in debugging and monitoring applications.
They are better than print statements.'''

# %%
# Q5] What is the significance of the __del__ method in Python

'''The __del__ method is called when an object is deleted.
It works as a destructor.
It helps release memory or resources.
It is automatically invoked by Python.
It supports memory management.'''

# %%
# Q6]  What is the difference between import and from ... import in Python

'''import module imports the whole module.
from module import item imports specific items.
The first keeps the namespace clear.
The second reduces typing.
Both are useful depending on need.'''

# %%
# Q7] How can you handle multiple exceptions in Python

'''Multiple exceptions can be handled using multiple except blocks.
Each block handles a specific error.
It improves error clarity.
Python also allows grouping exceptions.
This makes programs more robust.'''

# %%
# Q8] What is the purpose of the with statement when handling files in Python

'''The with statement simplifies file handling.
It automatically closes files.
It reduces the chance of memory leaks.
Code becomes cleaner and safer.
It is widely recommended.'''

# %%
# Q9 ] What is the difference between multithreading and multiprocessing

'''Multithreading runs multiple threads in the same process.
Multiprocessing runs multiple processes.
Threads share memory.
Processes have separate memory.
Multiprocessing avoids GIL limitations.'''

# %%
# Q10] What are the advantages of using logging in a program

'''Logging helps track program flow.
It makes debugging easier.
Logs can be saved to files.
Different severity levels are supported.
It is essential for production systems.'''

# %%
# Q11]  What is memory management in Python

'''Memory management controls memory allocation and deallocation.
Python handles memory automatically.
It uses reference counting and garbage collection.
Developers don’t manage memory manually.
This reduces errors.'''

# %%
# Q12] What are the basic steps involved in exception handling in Python

'''Place risky code inside try.
Handle errors using except.
Use else if no error occurs.
Use finally for cleanup.
This structure ensures safe execution.'''

# %%
# Q13]  Why is memory management important in Python

'''Proper memory management avoids crashes.
It improves performance.
It prevents memory leaks.
It allows efficient resource use.
It is crucial for large applications.'''

# %%
# Q14] What is the role of try and except in exception handling

'''try contains error-prone code.
except handles exceptions.
They prevent abrupt program termination.
Errors are handled gracefully.
They improve user experience.'''

# %%
# Q15]  How does Python's garbage collection system work

'''Python tracks object references.
When references reach zero, memory is freed.
The garbage collector removes unused objects.
It runs automatically.
This simplifies development.'''

# %%
# Q16] What is the purpose of the else block in exception handling

'''The else block runs if no exception occurs.
It separates normal logic from error handling.
It improves code clarity.
It avoids unnecessary checks.
It is optional but useful.'''

# %%
# Q17] What are the common logging levels in Python

'''DEBUG – detailed information
INFO – general events
WARNING – potential problems
ERROR – serious issues
CRITICAL – fatal errors'''

# %%
# Q18] What is the difference between os.fork() and multiprocessing in Python

'''os.fork() creates a child process in Unix systems.
Multiprocessing is cross-platform.
Multiprocessing is safer and easier.

os.fork() is low-level.
Multiprocessing is preferred.'''

# %%
# Q19]  What is the importance of closing a file in Python

'''Closing a file releases resources.
It prevents data corruption.
It avoids memory leaks.
It ensures data is saved properly.
Always close files after use.'''

# %%
# Q20] What is the difference between file.read() and file.readline() in Python

'''read() reads the entire file.
readline() reads one line at a time.
read() uses more memory.
readline() is memory-efficient.
Choice depends on file size.'''

# %%
# Q21] What is the logging module in Python used for

'''The logging module records messages.
It helps track application behavior.
It supports multiple log levels.
Logs can be written to files.
It replaces print debugging.'''

# %%
# Q22] What is the os module in Python used for in file handling

'''The os module interacts with the operating system.
It handles files and directories.
It checks file existence.
It manages paths.
It supports system-level tasks.'''

# %%
# Q23]  What are the challenges associated with memory management in Python

'''Large objects consume memory.
Memory leaks reduce performance.
Circular references are complex.
High memory usage slows programs.
Proper handling is required.'''

# %%
# Q24] How do you raise an exception manually in Python

'''Python allows raising exceptions using raise.
It is used for custom error handling.
Developers control error flow.
It improves validation.
It makes code safer.'''

# %%
# Q25]  Why is it important to use multithreading in certain applications?

'''Multithreading improves responsiveness.
It allows parallel tasks.
Useful for I/O-bound programs.
It reduces waiting time.
Used in servers and GUIs.'''

# %%
# Practical Questions

# %%
# Q1] How can you open a file for writing in Python and write a string to it

with open("data.txt", "w") as file:
    file.write("Hello Python")

# %%
# Q2] Write a Python program to read the contents of a file and print each line

with open("data.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello Python

# %%
# Q3]  How would you handle a case where the file doesn't exist while trying to open it for reading

try:
    open("test.txt")
except FileNotFoundError:
    print("File does not exist")
# Out:
# File does not exist

# %%
# Q4] Write a Python script that reads from one file and writes its content to another file

with open("source.txt") as src, open("dest.txt", "w") as dst:
    dst.write(src.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Q4] Write a Python script that reads from one file and writes its content to another file
# ----> 3 with open("source.txt") as src, open("dest.txt", "w") as dst:
#       4     dst.write(src.read())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
# Q5]  How would you catch and handle division by zero error in Python

try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# Q6]  Write a Python program that logs an error message to a log file when a division by zero exception occursF Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging
logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    10 / 0
except ZeroDivisionError:
    logging.error("Division by zero error")

# %%
#Q7] How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

logging.info("Info message")
logging.warning("Warning message")
logging.error("Error message")

# %%
# Q8] Write a program to handle a file opening error using exception handling

try:
    open("file.txt")
except IOError:
    print("Error opening file")
# Out:
# Error opening file

# %%
# Q9] How can you read a file line by line and store its content in a list in Python

with open("data.txt") as f:
    lines = f.readlines()

# %%
# Q10]  How can you append data to an existing file in Python

with open("data.txt", "a") as file:
    file.write("New line\n")

# %%
# Q11] Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist

try:
    d = {"a": 1}
    print(d["b"])
except KeyError:
    print("Key not found")
# Out:
# Key not found

# %%
# Q12]  Write a program that demonstrates using multiple except blocks to handle different types of exceptions


try:
    x = int("abc")
except ValueError:
    print("Value error")
except TypeError:
    print("Type error")
# Out:
# Value error

# %%
# Q13] How would you check if a file exists before attempting to read it in Python

import os
if os.path.exists("data.txt"):
    print("File exists")
# Out:
# File exists

# %%
# Q14] Write a program that uses the logging module to log both informational and error messages

logging.info("Program started")
logging.error("Something went wrong")

# %%
# Q15] Write a Python program that prints the content of a file and handles the case when the file is empty

with open("data.txt") as f:
    content = f.read()
    if not content:
        print("File is empty")

# %%
# Q16] Demonstrate how to use memory profiling to check the memory usage of a small program

import sys
a = [1,2,3]
print(sys.getsizeof(a))
# Out:
# 88

# %%
# Q17] Write a Python program to create and write a list of numbers to a file, one number per line

with open("numbers.txt", "w") as f:
    for i in range(1, 6):
        f.write(str(i) + "\n")

# %%
# Q18] How would you implement a basic logging setup that logs to a file with rotation after 1MB

from logging.handlers import RotatingFileHandler

# %%
# Q19] Write a program that handles both IndexError and KeyError using a try-except block

try:
    lst = []
    print(lst[0])
except (IndexError, KeyError):
    print("Error occurred")
# Out:
# Error occurred

# %%
# Q20] How would you open a file and read its contents using a context manager in Python

with open("data.txt") as file:
    print(file.read())
# Out:
# Hello PythonNew line

# %%
# Q21] Write a Python program that reads a file and prints the number of occurrences of a specific word
with open("data.txt") as f:
    text = f.read()
    print(text.count("python"))
# Out:
# 0

# %%
# Q22] How can you check if a file is empty before attempting to read its contents

import os
if os.stat("data.txt").st_size == 0:
    print("File is empty")

# %%
# Q23]  Write a Python program that writes to a log file when an error occurs during file handling.

try:
    open("abc.txt")
except Exception as e:
    logging.error(e)
